# %% [markdown]
# #### Streaming means the model starts sending tokens (words) as soon as they are generated instead of waiting for the entire response to be ready for returning
#
# Instead of .invoke(), use .stream() function
#
# This will return a python generator
#
# #### In python, generator is a special type of iterator that allows you to generate values on the fly,one at a time,using the yield keyword instead of return
#
# Loop on this generator and stream the response as one token at a time
